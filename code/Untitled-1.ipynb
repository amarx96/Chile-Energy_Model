# %%
from atlite.gis import ExclusionContainer
from atlite.gis import shape_availability
import atlite
import rasterio as rio
from rasterio.plot import show
import geopandas as gpd
import pandas as pd
import numpy as np
import xarray as xr
import os
import matplotlib.pyplot as plt
import rasterio.crs as crs

# %%
# Projection to use for a calculations
# ESRI:102033: South_America_Albers_Equal_Area_Conic
c = "ESRI:54017"

# %%
new_directory = r'C:\Users\alex-\Desktop\EW_Mod_Paper'
os.chdir(new_directory)
countries = gpd.read_file("./data/world-administrative-boundaries.geojson")
countries.drop(["status","color_code" ,"continent","iso_3166_1_alpha_2_codes","french_short"],axis=1,inplace=True)
countries = countries[countries["iso3"].isin(["DEU","FRA","ITA","SWE","DNK","AUT"])]
# Out:
#                                           geo_point_2d iso3     name  \
# 2    {'lon': 2.551955216777798, 'lat': 46.564502053...  FRA   France
# 13   {'lon': 14.14019348879525, 'lat': 47.592902606...  AUT  Austria
# 35   {'lon': 10.046298414692636, 'lat': 55.96339824...  DNK  Denmark
# 80   {'lon': 12.071742970356828, 'lat': 42.79578239...  ITA    Italy
# 137  {'lon': 10.393661554752802, 'lat': 51.10659218...  DEU  Germany
# 245  {'lon': 16.739754033053558, 'lat': 62.78989678...  SWE   Sweden
#
#               region                                           geometry
# 2     Western Europe  MULTIPOLYGON (((9.44750 42.68305, 9.45014 42.6...
# 13    Western Europe  POLYGON ((16.94618 48.61907, 16.94333 48.57333...
# 35   Northern Europe  MULTIPOLYGON (((11.51389 54.82972, 11.56444 54...
# 80   Southern Europe  MULTIPOLYGON (((15.52889 38.13694, 15.50361 38...
# 137   Western Europe  MULTIPOLYGON (((14.22555 53.92860, 14.21583 53...
# ...

# %%
countries.plot()
# Out:
# <Axes: >

# %%
countries[countries["iso3"]].isin(["DEU","FRA","ITA","SWE","DNK","AUT"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\alex-\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...
